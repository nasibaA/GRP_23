# %% [markdown]
# # warm-up

# %% [markdown]
# what is object-oriented? How have we used objects in the class?

# %% [markdown]
# Object oriented programmming helps us represent things in our code. Two big thing in object oriented are classes and objects. Class represents something such as a customer and then objects are specific examples of that.
#
# # class
# # customer
# # name
# # membership type
#
# so this is an example of class
# by creating our classes we can group things in logical units customers in this case and then we can instantiate this class into what are known as objects
#
# # name: Jhon
# # membership:bronze ---- so these both objects
#
#
# Object oriented programmming we basically difine structure in what's known as a class and then we use that class to create objects.

# %%
class Customer:
    def __init__(self, name, membership_type):
        self.name = name
        self.membership_type = membership_type
        #print("customer created")
        
c = Customer("Jhon","bronze")
print(c.name,c.membership_type)

# %%
import pymongo
import datetime

#connect to mongodb on default port
conn='mongodb://127.0.0.1:27017/'
client=pymongo.MongoClient(conn)

#create a database
sdb = client.shows_db

#create a collection in that DB
tv_shows = sdb.tv_shows

# %%
#CREATE
post_data = {'name':'My Life is Murder',
            'seasons':2,
             'duration':'45 minutes',
             'year':2019,
             'date_added':datetime.datetime.utcnow()
            }

tv_shows.insert_one(post_data)

# %%
#READ
results= tv_shows.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6220217c4255cefdabe6f63a'), 'name': 'My Life is Murder', 'seasons': 2, 'duration': '45 minutes', 'year': 2019, 'date_added': datetime.datetime(2022, 3, 3, 2, 1, 32, 712000)}
# {'_id': ObjectId('622133a55d889834f03cdd66'), 'name': 'My Life is Murder', 'seasons': 2, 'duration': '45 minutes', 'year': 2019, 'date_added': datetime.datetime(2022, 3, 3, 21, 31, 17, 342000)}

# %%
#DELETE
tv_shows.delete_one({'name':'Deamon Slayer'})

# %%
show_name = input("what show are you watching?")

# %% [markdown]
# 1. Expand the flask app from class to add functions to create, update, and delete records.
# Use the mongodb documentation https://docs.mongodb.com/manual/reference/ . Create
# can use insert_one method, update can use update_one, and delete can use
# delete_one

# %%
from flask import Flask,render_template
from flask_pymongo import PyMongo
import datetime
app = Flask(__name__)

#setup mongo connection
app.config['MONGO_URI']="mongodb://localhost:27017/shows_db"
mongo = PyMongo(app)

#connect to collection
tv_shows = mongo.db.tv_shows

#insert
@app.route("/insert")
def insert():
    post_data = {'name':'sugarrush',
                'seasons':3,
                'duration':'40 minutes',
                'year':2019,
                'data_added':datetime.datetime.utcnow()}
    #insert record
    tv_shows.insert_one(post_data)
    return 'data created'



 # update   
@app.route('/update')
def update():
    # item we want to update
    item ={'name':'House'}
    # the new value we want to set
    updated_val = {'$set':{'seasons':4}}
    # make the update
    tv_shows.update_one(item,updated_val)
    return 'data updated'

#DElete
@app.route('/delete')
def delete():
    #Delete the original record
    tv_shows.delete_one({'name':'House'})

    return 'data deleted'


#READ
@app.route("/read")
def read():
    #find all items in db and save to avariable
    all_shows = list(tv_shows.find())

    return render_template('index.html',data = all_shows)

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ![image.png](attachment:image.png)
